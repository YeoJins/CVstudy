# %%
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import cv2

# %%
images = '/content/drive/MyDrive/cvstudy/cutecats.jpg'

image = cv2.imread(images,1)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=900x900 at 0x7F6C8D9F4D90>
